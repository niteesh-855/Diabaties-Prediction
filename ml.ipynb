# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
df = pd.read_csv("https://raw.githubusercontent.com/shsarv/Machine-Learning-Projects/main/Diabetes%20Prediction%20%5BEND%202%20END%5D/dataset/kaggle_diabetes.csv")
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
y = df['Outcome']
x = df.drop('Outcome', axis = 1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
lr = LogisticRegression()
dr = DecisionTreeClassifier()

# %%
lr.fit(X_train,Y_train)
# Out:
# c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
dr.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
lr.score(X_train,Y_train)
# Out:
# 0.7673333333333333

# %%
lr.score(X_test,Y_test)
# Out:
# 0.794

# %%
dr.score(X_train,Y_train)
# Out:
# 1.0

# %%
dr.score(X_test,Y_test)
# Out:
# 0.962

# %%
from sklearn.model_selection import cross_val_score 
cross_val_score(dr,X_test,Y_test,cv=5)
# Out:
# array([0.77, 0.76, 0.89, 0.82, 0.78])

# %%
from sklearn.model_selection import cross_val_score 
cross_val_score(dr,X_train,Y_train,cv=5)
# Out:
# array([0.92333333, 0.92      , 0.95      , 0.95333333, 0.93333333])

# %%
from sklearn.model_selection import cross_val_score 
cross_val_score(lr,X_train,Y_train,cv=5)
# Out:
# c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.model_selection import cross_val_score 
cross_val_score(lr,X_test,Y_test,cv=5)
# Out:
# c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'C' : [0.01,0.1,1,10,100,1000],           #regularisation parameter
    'penalty':['l2','l1','elastinet'],   #penalty types
    'solver':['liblinear']  # Optimization algorithm
}

# %%
#Setup GridSearch with cross-val 
grid_search = GridSearchCV(estimator = lr,param_grid=param_grid,cv=5,scoring='accuracy')

#fit the model with the training data
grid_search.fit(X_train,Y_train)

#best hyperparametry found
best_params = grid_search.best_params_
print("Best Parameters:",best_params)
# Out:
# Best Parameters: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
# ...

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    1316
# 1     684
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test,lr.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       320
#            1       0.78      0.59      0.68       180
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.75      0.76       500
# weighted avg       0.79      0.79      0.79       500

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Y_test,lr.predict(X_test))
# Out:
# array([[290,  30],
#        [ 73, 107]])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

print(confusion_matrix(Y_test,lr.predict(X_test)))
print(accuracy_score(Y_test,lr.predict(X_test)))
print(precision_score(Y_test,lr.predict(X_test)))
print(recall_score(Y_test,lr.predict(X_test)))
print(f1_score(Y_test,lr.predict(X_test)))
# Out:
# [[290  30]
#  [ 73 107]]
# 0.794
# 0.781021897810219
# 0.5944444444444444
# 0.6750788643533123

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
df['Glucose'].value_counts()
# Out:
# Glucose
# 99     49
# 100    44
# 102    39
# 129    37
# 106    36
#        ..
# 177     2
# 191     2
# 67      2
# 186     2
# 198     2
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# project start

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
df['BloodPressure'] = df['BloodPressure'].replace(0, df['BloodPressure'].mean())

# %%
(df == 0).sum()
# Out:
# Pregnancies                  301
# Glucose                       13
# BloodPressure                  0
# SkinThickness                573
# Insulin                      956
# BMI                           28
# DiabetesPedigreeFunction       0
# Age                            0
# Outcome                     1316
# dtype: int64

# %%
df['BMI'] = df['BMI'].replace(0, df['BMI'].mean())

# %%
(df==0).sum()
# Out:
# Pregnancies                  301
# Glucose                       13
# BloodPressure                  0
# SkinThickness                573
# Insulin                      956
# BMI                            0
# DiabetesPedigreeFunction       0
# Age                            0
# Outcome                     1316
# dtype: int64

# %%
df['SkinThickness'] = df['SkinThickness'].replace(0, df['SkinThickness'].mean())

# %%
(df == 0 ).sum()
# Out:
# Pregnancies                  301
# Glucose                       13
# BloodPressure                  0
# SkinThickness                  0
# Insulin                      956
# BMI                            0
# DiabetesPedigreeFunction       0
# Age                            0
# Outcome                     1316
# dtype: int64

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138        62.0000         35.000        0  33.6
# 1               0       84        82.0000         31.000      125  38.2
# 2               0      145        69.1455         20.935        0  44.2
# 3               0      135        68.0000         42.000      250  42.3
# 4               1      139        62.0000         41.000      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75        64.0000         24.000       55  29.7
# 1996            8      179        72.0000         42.000      130  32.7
# 1997            6       85        78.0000         20.935        0  31.2
# 1998            0      129       110.0000         46.000      130  67.1
# 1999            2       81        72.0000         15.000       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
y = df['Outcome']
X = df.drop('Outcome',axis = 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
lg = LogisticRegression()
dr = DecisionTreeClassifier()

# %%
lg.fit(X_train,y_train)
# Out:
# c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lg.fit(X_test,y_test)
# Out:
# c:\Users\niteesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
dr.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("LogisticRegression", lg.score(X_train,y_train),lg.score(X_test,y_test))
print("DecisionTreeClassifier", dr.score(X_train,y_train), dr.score(X_test,y_test))
# Out:
# LogisticRegression 0.746 0.756
# DecisionTreeClassifier 1.0 0.966

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138        62.0000         35.000        0  33.6
# 1               0       84        82.0000         31.000      125  38.2
# 2               0      145        69.1455         20.935        0  44.2
# 3               0      135        68.0000         42.000      250  42.3
# 4               1      139        62.0000         41.000      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75        64.0000         24.000       55  29.7
# 1996            8      179        72.0000         42.000      130  32.7
# 1997            6       85        78.0000         20.935        0  31.2
# 1998            0      129       110.0000         46.000      130  67.1
# 1999            2       81        72.0000         15.000       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
(df==0).sum()
# Out:
# Pregnancies                  301
# Glucose                       13
# BloodPressure                  0
# SkinThickness                  0
# Insulin                      956
# BMI                            0
# DiabetesPedigreeFunction       0
# Age                            0
# Outcome                     1316
# dtype: int64

# %%
import pickle
with open('model.pickel','wb') as model_file:
           pickle.dump(lr,model_file)
